# %%
# 2. Filter df2 where 'Name' exists in df1's 'FAC_Name' column
matched_df = df2[df2['NAME'].isin(df1['FAC_NAME'])]

# 3. Save the result to a new CSV file
matched_df.to_csv('texas_obs_fac.csv', index=False)

# View the first few rows of the result
print(matched_df.head())
# Out:
#                      ADDRESS       ALT_NAME  BEDS           CITY COUNTRY  \
# 0     2600 HIGHWAY 118 NORTH  NOT AVAILABLE    25         ALPINE     USA
# 1            387 WEST I H 10  NOT AVAILABLE    25  FORT STOCKTON     USA
# 4      2000 TRANSMOUNTAIN RD  NOT AVAILABLE   108        EL PASO     USA
# 6   2001 NORTH OREGON STREET  NOT AVAILABLE   480        EL PASO     USA
# 17       4815 ALAMEDA AVENUE  NOT AVAILABLE   354        EL PASO     USA
#
#       COUNTY  COUNTYFIPS HELIPAD         ID   LATITUDE  ...     TRAUMA  \
# 0   BREWSTER       48043       N    5479830  30.383944  ...   LEVEL IV
# 1      PECOS       48371       Y   19879735  30.905379  ...   LEVEL IV
# 4    EL PASO       48141       Y  169079911  31.904574  ...   LEVEL IV
# 6    EL PASO       48141       Y   17979902  31.771004  ...  LEVEL III
# 17   EL PASO       48141       Y   17879998  31.771611  ...    LEVEL I
#
#     TTL_STAFF                TYPE    VAL_DATE     VAL_METHOD  \
# 0        -999     CRITICAL ACCESS -1281971200  IMAGERY/OTHER
# 1        -999     CRITICAL ACCESS   420996096  IMAGERY/OTHER
# 4        -999  GENERAL ACUTE CARE -1713128448  IMAGERY/OTHER
# 6        -999  GENERAL ACUTE CARE -1047803904        IMAGERY
# 17       -999  GENERAL ACUTE CARE   420996096  IMAGERY/OTHER
#
#                                               WEBSITE    ZIP           ZIP4  \
# 0                    http://www.bigbendhealthcare.com  79830  NOT AVAILABLE
# 1                                       NOT AVAILABLE  79735  NOT AVAILABLE
# 4   https://www.thehospitalsofprovidence.com/our-l...  79911  NOT AVAILABLE
# 6    http://www.sphn-pmh.com/en-us/pages/default.aspx  79902  NOT AVAILABLE
# 17                       http://www.thomasoncares.org  79905  NOT AVAILABLE
#
#                                              geometry  \
# 0   b"\x00\x00\x00\x00\x01\xc0Y\xea\xe9'\xccL\xc8@...
# 1   b"\x00\x00\x00\x00\x01\xc0Y\xb8X\x98'S\xac@>\x...
# 4   b'\x00\x00\x00\x00\x01\xc0Z\xa4(Y\x90j\x18@?\x...
# 6   b'\x00\x00\x00\x00\x01\xc0Z\x9f\xfd\xed5\xf8\x...
# 17  b'\x00\x00\x00\x00\x01\xc0Z\x9b\xdc\xdc\x0e\x8...
#
#                                                  bbox
# 0   {'xmin': -103.67048067999997, 'ymin': 30.38394...
# 1   {'xmin': -102.88040737, 'ymin': 30.90537931, '...
# 4   {'xmin': -106.56496275999996, 'ymin': 31.90457...
# 6   {'xmin': -106.49987345, 'ymin': 31.77100376000...
# 17  {'xmin': -106.4353552, 'ymin': 31.771611090000...
#
# [5 rows x 34 columns]

# %% [markdown]
# The file was downloaded from this link: https://source.coop/seerai/hifld/hospitals/hospitals/hospitals.parquet

# %%
import pandas as pd

# Define the path to your downloaded file
file_path = 'test_HIFLD.parquet'

try:
    # Read the parquet file
    df = pd.read_parquet(file_path)

    # Display basic information about the dataset
    print("File loaded successfully!")
    print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")

    # Show the first 5 rows
    print(df.head())

    # Optional: Filter for Texas immediately if this is the HIFLD data
    if 'STATE' in df.columns:
        df_tx = df[df['STATE'] == 'TX']
        print(f"Filtered to {len(df_tx)} Texas records.")

except Exception as e:
    print(f"Error reading the parquet file: {e}")
# Out:
# File loaded successfully!
# Rows: 8340, Columns: 34
#                        ADDRESS                    ALT_NAME   BEDS       CITY  \
# 0  FAGAALU VILLAGE, PO BOX LBJ               NOT AVAILABLE  150.0  PAGO PAGO
# 1      4643 WAIMEA CANYON ROAD               NOT AVAILABLE   25.0     WAIMEA
# 2         3-3420 KUHIO HIGHWAY               NOT AVAILABLE   72.0      LIHUE
# 3           4800 KAWAIHAU ROAD               NOT AVAILABLE   14.0      KAPAA
# 4     91-1010 SHANGRILA STREET  WARRIOR OHANA MEDICAL HOME -999.0    KAPOLEI
#
#   COUNTRY    COUNTY COUNTYFIPS HELIPAD          ID   LATITUDE  ...  \
# 0     ASM   EASTERN      60010       N  0000396799 -14.290242  ...
# 1     USA     KAUAI      15007       N  0196496796  21.960856  ...
# 2     USA     KAUAI      15007       N  0002996766  21.986148  ...
# 3     USA     KAUAI      15007       N  0002596746  22.087822  ...
# 4     USA  HONOLULU      15003       N  0196784557  21.319252  ...
#
#           TRAUMA TTL_STAFF                TYPE   VAL_DATE     VAL_METHOD  \
# 0  NOT AVAILABLE      -999  GENERAL ACUTE CARE  618828800  IMAGERY/OTHER
# 1  NOT AVAILABLE      -999     CRITICAL ACCESS -328299520  IMAGERY/OTHER
# 2      LEVEL III      -999  GENERAL ACUTE CARE  303119360        IMAGERY
# 3  NOT AVAILABLE      -999     CRITICAL ACCESS  303119360        IMAGERY
# 4  NOT AVAILABLE      -999            MILITARY -496241664  IMAGERY/OTHER
#
#                                              WEBSITE    ZIP           ZIP4  \
# 0                                      NOT AVAILABLE  96799  NOT AVAILABLE
# 1                             http://kauai.hhsc.org/  96796  NOT AVAILABLE
# 2        https://www.hawaiipacifichealth.org/wilcox/  96766  NOT AVAILABLE
# 3  http://kauai.hhsc.org/facilities/samuel-mahelo...  96746  NOT AVAILABLE
# 4  http://tripler.tricare.mil/clinics/warrior-oha...  96707           2102
#
#                                             geometry  \
# 0  b'\x00\x00\x00\x00\x01\xc0eU\xf1\x97\x1c\x10\x...
# 1  b'\x00\x00\x00\x00\x01\xc0c\xf5u\xb6z\xfb\xc9@...
# 2  b'\x00\x00\x00\x00\x01\xc0c\xeb\xadv\x0f\xa6\x...
# 3  b'\x00\x00\x00\x00\x01\xc0c\xea\x03\x13/\xdd\x...
# 4  b'\x00\x00\x00\x00\x01\xc0c\xc2F\xb7\xaa%\xd8@...
#
#                                                 bbox
# 0  {'xmin': -170.68574099999998, 'ymin': -14.2902...
# 1  {'xmin': -159.67061923999998, 'ymin': 21.96085...
# 2  {'xmin': -159.36492446, 'ymin': 21.98614785000...
# 3  {'xmin': -159.31287536, 'ymin': 22.08782195000...
# 4  {'xmin': -158.07113249999998, 'ymin': 21.31925...
#
# [5 rows x 34 columns]
# Filtered to 876 Texas records.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8340 entries, 0 to 8339
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ADDRESS     8340 non-null   object
#  1   ALT_NAME    8340 non-null   object
#  2   BEDS        8340 non-null   float64
#  3   CITY        8340 non-null   object
#  4   COUNTRY     8340 non-null   object
#  5   COUNTY      8340 non-null   object
#  6   COUNTYFIPS  8340 non-null   object
#  7   HELIPAD     8340 non-null   object
#  8   ID          8340 non-null   object
#  9   LATITUDE    8340 non-null   float64
#  10  LONGITUDE   8340 non-null   float64
#  11  NAICS_CODE  8340 non-null   object
#  12  NAICS_DESC  8340 non-null   object
#  13  NAME        8340 non-null   object
#  14  OBJECTID    8340 non-null   int32
#  15  OWNER       8340 non-null   object
#  16  POPULATION  8340 non-null   int32
#  17  SOURCE      8340 non-null   object
#  18  SOURCEDATE  8340 non-null   int32
#  19  STATE       8340 non-null   object
#  20  STATE_ID    8340 non-null   object
#  21  STATUS      8340 non-null   object
#  22  ST_FIPS     8340 non-null   object
#  23  TELEPHONE   8340 non-null   object
#  24  TRAUMA      8340 non-null   object
#  25  TTL_STAFF   8340 non-null   int32
#  26  TYPE        8340 non-null   object
#  27  VAL_DATE    8340 non-null   int32
#  28  VAL_METHOD  8340 non-null   object
#  29  WEBSITE     8340 non-null   object
#  30  ZIP         8340 non-null   object
#  31  ZIP4        8340 non-null   object
#  32  geometry    8340 non-null   object
#  33  bbox        8340 non-null   object
# dtypes: float64(3), int32(5), object(26)
# memory usage: 2.0+ MB

# %% [markdown]
# # Only looking at Texas data

# %%
df_tx = df[df['STATE'] == 'TX']
print(df_tx.head(1))
# Out:
#                      ADDRESS       ALT_NAME  BEDS    CITY COUNTRY    COUNTY  \
# 1020  2600 HIGHWAY 118 NORTH  NOT AVAILABLE  25.0  ALPINE     USA  BREWSTER
#
#      COUNTYFIPS HELIPAD          ID   LATITUDE  ...    TRAUMA TTL_STAFF  \
# 1020      48043       N  0005479830  30.383944  ...  LEVEL IV      -999
#
#                  TYPE    VAL_DATE     VAL_METHOD  \
# 1020  CRITICAL ACCESS -1281971200  IMAGERY/OTHER
#
#                                WEBSITE    ZIP           ZIP4  \
# 1020  http://www.bigbendhealthcare.com  79830  NOT AVAILABLE
#
#                                                geometry  \
# 1020  b"\x00\x00\x00\x00\x01\xc0Y\xea\xe9'\xccL\xc8@...
#
#                                                    bbox
# 1020  {'xmin': -103.67048067999997, 'ymin': 30.38394...
#
# [1 rows x 34 columns]

# %%
# The number of rows and columns in Texas data
print(f"Rows: {df_tx.shape[0]}, Columns: {df_tx.shape[1]}")
# Out:
# Rows: 876, Columns: 34

# %%
# Save the Texas subset to a CSV file
df_tx.to_csv('texas_hospitals_subset.csv', index=False)

print("Success! Your file has been saved as 'texas_hospitals_subset.csv'.")
# Out:
# Success! Your file has been saved as 'texas_hospitals_subset.csv'.

# %% [markdown]
# # Cross-reference CMOS data with Texas Data to find Obstetric facilities

# %%
import pandas as pd

# Load your CSV files
df1 = pd.read_csv('Cleaned_CMOS_Data.csv')
df2 = pd.read_csv('Cleaned_texas_hospitals_HIFLD.csv')
# Out:
# /tmp/ipykernel_731/2524279255.py:4: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('Cleaned_CMOS_Data.csv')

# %%
print(df1.head())
# Out:
#    PRVDR_CTGRY_SBTYP_CD  PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT    CITY_NAME  \
# 0                     1               1         1  20100701.0     FLORENCE
# 1                     1               1         3  20151003.0    ALABASTER
# 2                     1               1         2         NaN  PHENIX CITY
# 3                     1               1         0         NaN  CENTREVILLE
# 4                     1               1         1         NaN    SYLACAUGA
#
#   ACPTBL_POC_SW CMPLNC_STUS_CD  SSA_CNTY_CD CROSS_REF_PROVIDER_NUMBER  \
# 0             N              B        380.0                       NaN
# 1             N              B        580.0                       NaN
# 2             N              A        560.0                       NaN
# 3             N              B         30.0                       NaN
# 4             N              B        600.0                     10072
#
#    CRTFCTN_DT  ... ENDSCPY_SRGRY_SW OB_GYN_SRGRY_SW  OTHR_SRGRY_SW  \
# 0    20190411  ...              NaN             NaN            NaN
# 1    20121213  ...              NaN             NaN            NaN
# 2    20010605  ...              NaN             NaN            NaN
# 3    20240801  ...              NaN             NaN            NaN
# 4    20181115  ...              NaN             NaN            NaN
#
#   FT_SRGRY_SW  SB_SW  SB_SIZE_CD  TCHNLGST_2_YR_RDLGC_CNT  \
# 0         NaN      N         NaN                      NaN
# 1         NaN      N         NaN                      NaN
# 2         NaN      N         NaN                      NaN
# 3         NaN      Y         1.0                      NaN
# 4         NaN      N         NaN                      NaN
#
#    TCHNLGST_ASCT_DGR_CNT  TCHNLGST_BS_BA_DGR_CNT DLYS_STN_CNT
# 0                    NaN                     NaN          NaN
# 1                    NaN                     NaN          NaN
# 2                    NaN                     NaN          NaN
# 3                    NaN                     NaN          NaN
# 4                    NaN                     NaN          NaN
#
# [5 rows x 396 columns]

# %%
print(df2.head())
# Out:
#                    ADDRESS       ALT_NAME  BEDS           CITY COUNTRY  \
# 0   2600 HIGHWAY 118 NORTH  NOT AVAILABLE    25         ALPINE     USA
# 1          387 WEST I H 10  NOT AVAILABLE    25  FORT STOCKTON     USA
# 2    600 HIGHWAY 349 NORTH  NOT AVAILABLE    14          IRAAN     USA
# 3  1390 NORTHWESTERN DRIVE  NOT AVAILABLE    80        EL PASO     USA
# 4    2000 TRANSMOUNTAIN RD  NOT AVAILABLE   108        EL PASO     USA
#
#      COUNTY  COUNTYFIPS HELIPAD         ID   LATITUDE  ...         TRAUMA  \
# 0  BREWSTER       48043       N    5479830  30.383944  ...       LEVEL IV
# 1     PECOS       48371       Y   19879735  30.905379  ...       LEVEL IV
# 2     PECOS       48371       Y   30679744  30.914831  ...       LEVEL IV
# 3   EL PASO       48141       N  196784176  31.879894  ...  NOT AVAILABLE
# 4   EL PASO       48141       Y  169079911  31.904574  ...       LEVEL IV
#
#    TTL_STAFF                TYPE    VAL_DATE     VAL_METHOD  \
# 0       -999     CRITICAL ACCESS -1281971200  IMAGERY/OTHER
# 1       -999     CRITICAL ACCESS   420996096  IMAGERY/OTHER
# 2       -999     CRITICAL ACCESS   420996096  IMAGERY/OTHER
# 3       -999         PSYCHIATRIC  -496241664  IMAGERY/OTHER
# 4       -999  GENERAL ACUTE CARE -1713128448  IMAGERY/OTHER
#
#                                              WEBSITE    ZIP           ZIP4  \
# 0                   http://www.bigbendhealthcare.com  79830  NOT AVAILABLE
# 1                                      NOT AVAILABLE  79735  NOT AVAILABLE
# 2                                      NOT AVAILABLE  79744  NOT AVAILABLE
# 3                                      NOT AVAILABLE  79912  NOT AVAILABLE
# 4  https://www.thehospitalsofprovidence.com/our-l...  79911  NOT AVAILABLE
#
#                                             geometry  \
# 0  b"\x00\x00\x00\x00\x01\xc0Y\xea\xe9'\xccL\xc8@...
# 1  b"\x00\x00\x00\x00\x01\xc0Y\xb8X\x98'S\xac@>\x...
# 2  b'\x00\x00\x00\x00\x01\xc0Yz\x13\x91A\xdcD@>\x...
# 3  b'\x00\x00\x00\x00\x01\xc0Z\xa4\xb4\x9a\xa6\xd...
# 4  b'\x00\x00\x00\x00\x01\xc0Z\xa4(Y\x90j\x18@?\x...
#
#                                                 bbox
# 0  {'xmin': -103.67048067999997, 'ymin': 30.38394...
# 1  {'xmin': -102.88040737, 'ymin': 30.90537931, '...
# 2  {'xmin': -101.90744430000001, 'ymin': 30.91483...
# 3  {'xmin': -106.57352319999995, 'ymin': 31.87989...
# 4  {'xmin': -106.56496275999996, 'ymin': 31.90457...
#
# [5 rows x 34 columns]

# %%
# 2. Filter df2 where 'Name' exists in df1's 'FAC_Name' column
matched_df = df2[df2['NAME'].isin(df1['FAC_NAME'])]

# 3. Save the result to a new CSV file
matched_df.to_csv('texas_obs_fac.csv', index=False)

# View the first few rows of the result
print(matched_df.head())
# Out:
#                      ADDRESS       ALT_NAME  BEDS           CITY COUNTRY  \
# 0     2600 HIGHWAY 118 NORTH  NOT AVAILABLE    25         ALPINE     USA
# 1            387 WEST I H 10  NOT AVAILABLE    25  FORT STOCKTON     USA
# 4      2000 TRANSMOUNTAIN RD  NOT AVAILABLE   108        EL PASO     USA
# 6   2001 NORTH OREGON STREET  NOT AVAILABLE   480        EL PASO     USA
# 17       4815 ALAMEDA AVENUE  NOT AVAILABLE   354        EL PASO     USA
#
#       COUNTY  COUNTYFIPS HELIPAD         ID   LATITUDE  ...     TRAUMA  \
# 0   BREWSTER       48043       N    5479830  30.383944  ...   LEVEL IV
# 1      PECOS       48371       Y   19879735  30.905379  ...   LEVEL IV
# 4    EL PASO       48141       Y  169079911  31.904574  ...   LEVEL IV
# 6    EL PASO       48141       Y   17979902  31.771004  ...  LEVEL III
# 17   EL PASO       48141       Y   17879998  31.771611  ...    LEVEL I
#
#     TTL_STAFF                TYPE    VAL_DATE     VAL_METHOD  \
# 0        -999     CRITICAL ACCESS -1281971200  IMAGERY/OTHER
# 1        -999     CRITICAL ACCESS   420996096  IMAGERY/OTHER
# 4        -999  GENERAL ACUTE CARE -1713128448  IMAGERY/OTHER
# 6        -999  GENERAL ACUTE CARE -1047803904        IMAGERY
# 17       -999  GENERAL ACUTE CARE   420996096  IMAGERY/OTHER
#
#                                               WEBSITE    ZIP           ZIP4  \
# 0                    http://www.bigbendhealthcare.com  79830  NOT AVAILABLE
# 1                                       NOT AVAILABLE  79735  NOT AVAILABLE
# 4   https://www.thehospitalsofprovidence.com/our-l...  79911  NOT AVAILABLE
# 6    http://www.sphn-pmh.com/en-us/pages/default.aspx  79902  NOT AVAILABLE
# 17                       http://www.thomasoncares.org  79905  NOT AVAILABLE
#
#                                              geometry  \
# 0   b"\x00\x00\x00\x00\x01\xc0Y\xea\xe9'\xccL\xc8@...
# 1   b"\x00\x00\x00\x00\x01\xc0Y\xb8X\x98'S\xac@>\x...
# 4   b'\x00\x00\x00\x00\x01\xc0Z\xa4(Y\x90j\x18@?\x...
# 6   b'\x00\x00\x00\x00\x01\xc0Z\x9f\xfd\xed5\xf8\x...
# 17  b'\x00\x00\x00\x00\x01\xc0Z\x9b\xdc\xdc\x0e\x8...
#
#                                                  bbox
# 0   {'xmin': -103.67048067999997, 'ymin': 30.38394...
# 1   {'xmin': -102.88040737, 'ymin': 30.90537931, '...
# 4   {'xmin': -106.56496275999996, 'ymin': 31.90457...
# 6   {'xmin': -106.49987345, 'ymin': 31.77100376000...
# 17  {'xmin': -106.4353552, 'ymin': 31.771611090000...
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Adding obstetric service levels

# %%
import pandas as pd

# Load the texas_obs_fac.csv file
df_texas_obs_fac = pd.read_csv('texas_obs_fac.csv')

# Ensure df1 (Cleaned_CMOS_Data.csv) is loaded, if not already.
# Assuming df1 is already loaded from previous cells. If not, uncomment the line below:
# df1 = pd.read_csv('Cleaned_CMOS_Data.csv')

# Merge df_texas_obs_fac with df1 to bring in the 'OB_SRVC_CD' column
# We'll merge on 'NAME' from df_texas_obs_fac and 'FAC_NAME' from df1.
# A left merge will keep all records from df_texas_obs_fac.
combined_df = pd.merge(df_texas_obs_fac, df1[['FAC_NAME', 'OB_SRVC_CD']],
                     left_on='NAME', right_on='FAC_NAME', how='left')

# Drop the redundant 'FAC_NAME' column that came from df1 after the merge
combined_df.drop(columns=['FAC_NAME'], inplace=True, errors='ignore')

# Remove any potential duplicate rows that might have been introduced by the merge
original_rows = combined_df.shape[0]
combined_df.drop_duplicates(inplace=True)
print(f"Removed {original_rows - combined_df.shape[0]} duplicate rows.")

# Save the result to a new CSV file
output_filename = 'texas_obs_fac_with_ob_srvc.csv'
combined_df.to_csv(output_filename, index=False)

print(f"Successfully created '{output_filename}' with OB_SRVC_CD column.")
print("Here are the first few rows of the new combined dataframe:")
print(combined_df.head())
# Out:
# Removed 86 duplicate rows.
# Successfully created 'texas_obs_fac_with_ob_srvc.csv' with OB_SRVC_CD column.
# Here are the first few rows of the new combined dataframe:
#                     ADDRESS       ALT_NAME  BEDS           CITY COUNTRY  \
# 0    2600 HIGHWAY 118 NORTH  NOT AVAILABLE    25         ALPINE     USA
# 1    2600 HIGHWAY 118 NORTH  NOT AVAILABLE    25         ALPINE     USA
# 3           387 WEST I H 10  NOT AVAILABLE    25  FORT STOCKTON     USA
# 4     2000 TRANSMOUNTAIN RD  NOT AVAILABLE   108        EL PASO     USA
# 5  2001 NORTH OREGON STREET  NOT AVAILABLE   480        EL PASO     USA
#
#      COUNTY  COUNTYFIPS HELIPAD         ID   LATITUDE  ...  TTL_STAFF  \
# 0  BREWSTER       48043       N    5479830  30.383944  ...       -999
# 1  BREWSTER       48043       N    5479830  30.383944  ...       -999
# 3     PECOS       48371       Y   19879735  30.905379  ...       -999
# 4   EL PASO       48141       Y  169079911  31.904574  ...       -999
# 5   EL PASO       48141       Y   17979902  31.771004  ...       -999
#
#                  TYPE    VAL_DATE     VAL_METHOD  \
# 0     CRITICAL ACCESS -1281971200  IMAGERY/OTHER
# 1     CRITICAL ACCESS -1281971200  IMAGERY/OTHER
# 3     CRITICAL ACCESS   420996096  IMAGERY/OTHER
# 4  GENERAL ACUTE CARE -1713128448  IMAGERY/OTHER
# 5  GENERAL ACUTE CARE -1047803904        IMAGERY
#
#                                              WEBSITE    ZIP           ZIP4  \
# 0                   http://www.bigbendhealthcare.com  79830  NOT AVAILABLE
# 1                   http://www.bigbendhealthcare.com  79830  NOT AVAILABLE
# 3                                      NOT AVAILABLE  79735  NOT AVAILABLE
# 4  https://www.thehospitalsofprovidence.com/our-l...  79911  NOT AVAILABLE
# 5   http://www.sphn-pmh.com/en-us/pages/default.aspx  79902  NOT AVAILABLE
#
#                                             geometry  \
# 0  b"\x00\x00\x00\x00\x01\xc0Y\xea\xe9'\xccL\xc8@...
# 1  b"\x00\x00\x00\x00\x01\xc0Y\xea\xe9'\xccL\xc8@...
# 3  b"\x00\x00\x00\x00\x01\xc0Y\xb8X\x98'S\xac@>\x...
# 4  b'\x00\x00\x00\x00\x01\xc0Z\xa4(Y\x90j\x18@?\x...
# 5  b'\x00\x00\x00\x00\x01\xc0Z\x9f\xfd\xed5\xf8\x...
#
#                                                 bbox OB_SRVC_CD
# 0  {'xmin': -103.67048067999997, 'ymin': 30.38394...          3
# 1  {'xmin': -103.67048067999997, 'ymin': 30.38394...          1
# 3  {'xmin': -102.88040737, 'ymin': 30.90537931, '...          1
# 4  {'xmin': -106.56496275999996, 'ymin': 31.90457...          3
# 5  {'xmin': -106.49987345, 'ymin': 31.77100376000...          1
#
# [5 rows x 35 columns]

# %%
print('Column names for df1:')
print(df1.columns.tolist())
# Out:
# Column names for df1:
# ['PRVDR_CTGRY_SBTYP_CD', 'PRVDR_CTGRY_CD', 'CHOW_CNT', 'CHOW_DT', 'CITY_NAME', 'ACPTBL_POC_SW', 'CMPLNC_STUS_CD', 'SSA_CNTY_CD', 'CROSS_REF_PROVIDER_NUMBER', 'CRTFCTN_DT', 'ELGBLTY_SW', 'FAC_NAME', 'INTRMDRY_CARR_CD', 'MDCD_VNDR_NUM', 'ORGNL_PRTCPTN_DT', 'CHOW_PRIOR_DT', 'INTRMDRY_CARR_PRIOR_CD', 'PRVDR_NUM', 'RGN_CD', 'SKLTN_REC_SW', 'STATE_CD', 'SSA_STATE_CD', 'STATE_RGN_CD', 'ST_ADR', 'PHNE_NUM', 'PGM_TRMNTN_CD', 'TRMNTN_EXPRTN_DT', 'CRTFCTN_ACTN_TYPE_CD', 'GNRL_CNTL_TYPE_CD', 'ZIP_CD', 'FIPS_STATE_CD', 'FIPS_CNTY_CD', 'CBSA_URBN_RRL_IND', 'CBSA_CD', 'ACRDTN_EFCTV_DT', 'ACRDTN_EXPRTN_DT', 'ACRDTN_TYPE_CD', 'TOT_AFLTD_AMBLNC_SRVC_CNT', 'TOT_AFLTD_ASC_CNT', 'TOT_COLCTD_HOSP_CNT', 'TOT_AFLTD_ESRD_CNT', 'TOT_AFLTD_FQHC_CNT', 'TOT_AFLTD_HHA_CNT', 'TOT_AFLTD_HOSPC_CNT', 'TOT_AFLTD_OPO_CNT', 'TOT_AFLTD_PRTF_CNT', 'TOT_AFLTD_RHC_CNT', 'TOT_AFLTD_SNF_CNT', 'AFLTD_PRVDR_CNT', 'RSDNT_PGM_ALPTHC_SW', 'RSDNT_PGM_DNTL_SW', 'RSDNT_PGM_OSTPTHC_SW', 'RSDNT_PGM_OTHR_SW', 'RSDNT_PGM_PDTRC_SW', 'LAB_SRVC_CD', 'PHRMCY_SRVC_CD', 'RDLGY_SRVC_CD', 'ASC_BGN_SRVC_DT', 'FREESTNDNG_ASC_SW', 'OVRRD_BED_CNT_SW', 'CRTFD_BED_CNT', 'ICFIID_BED_CNT', 'MDCD_NF_BED_CNT', 'MDCR_SNF_BED_CNT', 'MDCR_MDCD_SNF_BED_CNT', 'AIDS_BED_CNT', 'ALZHMR_BED_CNT', 'DLYS_BED_CNT', 'DSBL_CHLDRN_BED_CNT', 'HEAD_TRMA_BED_CNT', 'HOSPC_BED_CNT', 'HNTGTN_DEASE_BED_CNT', 'REHAB_BED_CNT', 'VNTLTR_BED_CNT', 'BED_CNT', 'BRNCH_CNT', 'BRNCH_OPRTN_SW', 'CAH_PSYCH_DPU_SW', 'CAH_REHAB_DPU_SW', 'CAH_SB_SW', 'CRDC_CTHRTZTN_PRCDR_ROOMS_CNT', 'GNRL_FAC_TYPE_CD', 'CHOW_SW', 'CLIA_ID_NUMBER_1', 'CLIA_ID_NUMBER_2', 'CLIA_ID_NUMBER_3', 'CLIA_ID_NUMBER_4', 'CLIA_ID_NUMBER_5', 'COLCTN_STUS_SW', 'RN_24_HR_WVR_SW', 'RN_7_DAY_WVR_SW', 'BED_PER_ROOM_WVR_SW', 'LSC_WVR_SW', 'ROOM_SIZE_WVR_SW', 'ENDSCPY_PRCDR_ROOMS_CNT', 'ESRD_NTWRK_NUM', 'EXPRMT_RSRCH_CNDCTD_SW', 'FAX_PHNE_NUM', 'FY_END_MO_DAY_CD', 'FQHC_APPROVED_RHC_PROVIDER_NUM', 'FED_FUNDD_FQHC_SW', 'HHA_QLFYD_OPT_SPCH_SW', 'HH_AIDE_TRNG_PGM_CD', 'HOME_TRNG_SPRT_ONLY_SRVC_SW', 'MDCR_HOSPC_SW', 'HOSP_BSD_SW', 'INCNTR_NCTRNL_SRVC_SW', 'LTC_CROSS_REF_PROVIDER_NUMBER', 'MDCL_SCHL_AFLTN_CD', 'MEDICARE_HOSPICE_PROVIDER_NUM', 'MDCD_MDCR_PRTCPTG_PRVDR_SW', 'MEDICARE_MEDICAID_PRVDR_NUMBER', 'MLT_FAC_ORG_NAME', 'MLT_OWND_FAC_ORG_SW', 'NCRY_PRVDR_DSGNTD_DT', 'NCRY_PRVDR_DSGNTD_AS_SW', 'NCRY_PRVDR_LOST_DT', 'MEET_1861_SW', 'NPP_TYPE_CD', 'TOT_OFSITE_CNCR_HOSP_CNT', 'TOT_OFSITE_CHLDRN_HOSP_CNT', 'TOT_OFSITE_EMER_DEPT_CNT', 'TOT_OFSITE_INPTNT_LCTN_CNT', 'TOT_OFSITE_LTC_HOSP_CNT', 'TOT_OFSITE_OPTHLMC_SRGRY_CNT', 'TOT_OFSITE_OTHR_LCTN_CNT', 'TOT_OFSITE_PSYCH_HOSP_CNT', 'TOT_OFSITE_PSYCH_UNIT_CNT', 'TOT_OFSITE_REHAB_HOSP_CNT', 'TOT_OFSITE_REHAB_UNIT_CNT', 'TOT_OFSITE_URGNT_CARE_CNTR_CNT', 'OFSITE_LCTN_CNT', 'OPRTG_ROOM_CNT', 'ORGNZ_FMLY_MBR_GRP_SW', 'ORGNZ_RSDNT_GRP_SW', 'PARENT_PROVIDER_NUMBER', 'FQHC_APRVD_RHC_SW', 'MDCR_PRTCPTN_OP_PT_SPCH_SW', 'PGM_PRTCPTN_CD', 'PRVDR_BSD_FAC_SW', 'PRVNC_CD', 'PSYCH_UNIT_BED_CNT', 'PSYCH_UNIT_EFCTV_DT', 'PSYCH_UNIT_SW', 'PSYCH_UNIT_TRMNTN_CD', 'PSYCH_UNIT_TRMNTN_DT', 'REHAB_UNIT_BED_CNT', 'REHAB_UNIT_EFCTV_DT', 'REHAB_UNIT_SW', 'REHAB_UNIT_TRMNTN_CD', 'REHAB_UNIT_TRMNTN_DT', 'RELATED_PROVIDER_NUMBER', 'ACUTE_RNL_DLYS_SRVC_CD', 'PSYCH_SRVC_CD', 'HH_AIDE_SRVC_CD', 'ALCHL_DRUG_SRVC_CD', 'ANSTHSA_SRVC_CD', 'APLNC_EQUIP_SRVC_CD', 'AUDLGY_SRVC_CD', 'BLOOD_SRVC_OFSITE_RSDNT_SW', 'BLOOD_SRVC_ONST_NRSDNT_SW', 'BLOOD_SRVC_ONST_RSDNT_SW', 'BURN_CARE_UNIT_SRVC_CD', 'CRDC_CTHRTZTN_LAB_SRVC_CD', 'OPEN_HRT_SRGRY_SRVC_CD', 'CARF_IP_REHAB_SRVC_CD', 'CHMTHRPY_SRVC_CD', 'CHRPRCTIC_SRVC_CD', 'CL_SRVC_OFSITE_RSDNT_SW', 'CL_SRVC_ONST_NRSDNT_SW', 'CL_SRVC_ONST_RSDNT_SW', 'CL_SRVC_CD', 'CRNRY_CARE_UNIT_SRVC_CD', 'CNSLNG_SRVC_CD', 'CT_SCAN_SRVC_CD', 'DNTL_SRVC_CD', 'DNTL_SRVC_OFSITE_RSDNT_SW', 'DNTL_SRVC_ONST_NRSDNT_SW', 'DNTL_SRVC_ONST_RSDNT_SW', 'SHCK_TRMA_SRVC_CD', 'DGNSTC_RDLGY_SRVC_CD', 'DTRY_SRVC_CD', 'DTRY_OFSITE_RSDNT_SW', 'DTRY_ONST_NRSDNT_SW', 'DTRY_ONST_RSDNT_SW', 'DCTD_ER_SRVC_CD', 'EMER_PSYCH_SRVC_CD', 'XTRCRPRL_SHCK_LTHTRPTR_SRVC_CD', 'FRNSC_PS ...

# %%
print('\nColumn names for df2:')
print(df2.columns.tolist())
# Out:
# Column names for df2:
# ['ADDRESS', 'ALT_NAME', 'BEDS', 'CITY', 'COUNTRY', 'COUNTY', 'COUNTYFIPS', 'HELIPAD', 'ID', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE', 'NAICS_DESC', 'NAME', 'OBJECTID', 'OWNER', 'POPULATION', 'SOURCE', 'SOURCEDATE', 'STATE', 'STATE_ID', 'STATUS', 'ST_FIPS', 'TELEPHONE', 'TRAUMA', 'TTL_STAFF', 'TYPE', 'VAL_DATE', 'VAL_METHOD', 'WEBSITE', 'ZIP', 'ZIP4', 'geometry', 'bbox']

# %%
print('Column names for df2:')
print(df2.columns.tolist())

# %% [markdown]
# # **Shape file for TX counties**

# %%
import geopandas as gpd

# URL for the US Census 2023 County Shapefile (500k resolution, which is perfect for mapping)
census_url = "https://www2.census.gov/geo/tiger/GENZ2023/shp/cb_2023_us_county_500k.zip"

print("Downloading US County boundaries...")
# Geopandas can read zip URLs directly!
us_counties = gpd.read_file(census_url)

# Texas's State FIPS code is '48'
# The Census uses 'STATEFP' or 'STATEFP20' depending on the version
state_col = 'STATEFP' if 'STATEFP' in us_counties.columns else 'STATEFP20'

print("Filtering for Texas...")
tx_counties = us_counties[us_counties[state_col] == '48']

# Save it to your computer as a Shapefile bundle
tx_counties.to_file("texas_counties_shapefile.shp")
print("Saved successfully! 'texas_counties_shapefile.zip' (and its sidecars) are ready.")
# Out:
# Downloading US County boundaries...
# Filtering for Texas...
# Saved successfully! 'texas_counties_shapefile.zip' (and its sidecars) are ready.

# %% [markdown]
# ## Using Lat-long to find which hospital falls under what county (Not needed since the original file already have County info)

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# 1. Load your Texas shapefile
# (Ensure all sidecar files like .shx, .dbf, and .prj are in the same folder)
counties = gpd.read_file("texas_counties_shapefile.shp")

# 2. Load your hospital CSV data
hospitals_df = pd.read_csv("texas_obs_fac.csv")

# 3. Convert the Pandas DataFrame into a GeoDataFrame
# We create a 'geometry' column using the Longitude and Latitude.
# WARNING: Point takes (Longitude, Latitude) in that exact order: (X, Y)
geometry = [Point(xy) for xy in zip(hospitals_df['LONGITUDE'], hospitals_df['LATITUDE'])]

# WGS84 (EPSG:4326) is the standard coordinate system for raw Lat/Long
hospitals_gdf = gpd.GeoDataFrame(hospitals_df, geometry=geometry, crs="EPSG:4326")

# 4. Align coordinate reference systems (CRS)
# The shapefile and the points MUST be in the same projection to match properly.
if counties.crs != hospitals_gdf.crs:
    counties = counties.to_crs(hospitals_gdf.crs)

# 5. Perform the Spatial Join ('sjoin')
# 'predicate="within"' checks if the hospital point is WITHIN a county polygon
joined_df = gpd.sjoin(hospitals_gdf, counties, how="left", predicate="within")

# 6. Save your new dataset
# joined_df will now contain all your original hospital data PLUS the
# county columns from the shapefile (like GEOID, County Name, etc.)
joined_df.to_csv("hospitals_with_counties.csv", index=False)

print("Spatial join complete! Check 'hospitals_with_counties.csv'.")
# Out:
# Spatial join complete! Check 'hospitals_with_counties.csv'.
